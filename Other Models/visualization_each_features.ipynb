# %%
# Import necessary libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Create visualization color list

# %%
def visualizeV1(data):
    # Get the 'unit_number' column for the x-axis
    engine_unit = data['RUL']
    
    # Get the feature columns (all numeric columns except 'unit_nr')
    feature_columns = data.select_dtypes(include=[np.number]).drop(columns=['RUL']).columns
    
    features_column_size = len(feature_columns)
    
    # Define a list of colors for plotting
    color_list = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

    # Create subplots based on the number of features
    fig, axes = plt.subplots(nrows=int(np.ceil(features_column_size / 2)), ncols=2, figsize=(14, features_column_size * 2), dpi=80, facecolor="w", edgecolor="k")

    for i in range(features_column_size):
        key = feature_columns[i]
        c = color_list[i % len(color_list)]
        t_data = data[key]
        t_data.index = engine_unit
        
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{}".format(key),
            rot=25
        )
        ax.legend([key])

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Visulization for Train set

# %%
# Import training data
train_data = pd.read_csv('final_train.csv')
train_data.head()
# Out:
#    unit_number  time_cycle  setting_1  setting_2  setting_3  sensor_1  \
# 0            1           1    -0.0007    -0.0004      100.0    518.67
# 1            1           2     0.0019    -0.0003      100.0    518.67
# 2            1           3    -0.0043     0.0003      100.0    518.67
# 3            1           4     0.0007     0.0000      100.0    518.67
# 4            1           5    -0.0019    -0.0002      100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    641.82   1589.70   1400.60     14.62  ...    2388.02    8138.62
# 1    642.15   1591.82   1403.14     14.62  ...    2388.07    8131.49
# 2    642.35   1587.99   1404.20     14.62  ...    2388.03    8133.23
# 3    642.35   1582.79   1401.87     14.62  ...    2388.08    8133.83
# 4    642.37   1582.85   1406.22     14.62  ...    2388.04    8133.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
# Visualize
visualizeV1(train_data)
