# %%
# Import Necessary Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load Train Test Raw Data
raw_train_data = pd.read_csv("data/train_FD001.txt", sep=' ', header = None)
raw_test_data = pd.read_csv("data/test_FD001.txt", sep=' ', header = None)

# %%
# Check train dataset
raw_train_data
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...       18      19    20   21    22     23     24       25  \
# 0      14.62  ...  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1      14.62  ...  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2      14.62  ...  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3      14.62  ...  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4      14.62  ...  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# ...      ...  ...      ...     ...   ...  ...   ...    ...    ...      ...
# 20626  14.62  ...  8137.60  8.4956  0.03  397  2388  100.0  38.49  22.9735
# 20627  14.62  ...  8136.50  8.5139  0.03  395  2388  100.0  38.30  23.1594
# 20628  14.62  ...  8141.05  8.5646  0.03  398  2388  100.0  38.44  22.9333
# 20629  14.62  ...  8139.29  8.5389  0.03  395  2388  100.0  38.29  23.0640
# 20630  14.62  ...  8137.33  8.5036  0.03  396  2388  100.0  38.37  23.0522
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 20626 NaN NaN
# 20627 NaN NaN
# 20628 NaN NaN
# 20629 NaN NaN
# 20630 NaN NaN
#
# [20631 rows x 28 columns]

# %%
# Check train dataset
raw_test_data
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1  0.0023  0.0003  100.0  518.67  643.02  1585.29  1398.21
# 1        1    2 -0.0027 -0.0003  100.0  518.67  641.71  1588.45  1395.42
# 2        1    3  0.0003  0.0001  100.0  518.67  642.46  1586.94  1401.34
# 3        1    4  0.0042  0.0000  100.0  518.67  642.44  1584.12  1406.42
# 4        1    5  0.0014  0.0000  100.0  518.67  642.51  1587.19  1401.92
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 13091  100  194  0.0049  0.0000  100.0  518.67  643.24  1599.45  1415.79
# 13092  100  195 -0.0011 -0.0001  100.0  518.67  643.22  1595.69  1422.05
# 13093  100  196 -0.0006 -0.0003  100.0  518.67  643.44  1593.15  1406.82
# 13094  100  197 -0.0038  0.0001  100.0  518.67  643.26  1594.99  1419.36
# 13095  100  198  0.0013  0.0003  100.0  518.67  642.95  1601.62  1424.99
#
#           9   ...       18      19    20   21    22     23     24       25  \
# 0      14.62  ...  8125.55  8.4052  0.03  392  2388  100.0  38.86  23.3735
# 1      14.62  ...  8139.62  8.3803  0.03  393  2388  100.0  39.02  23.3916
# 2      14.62  ...  8130.10  8.4441  0.03  393  2388  100.0  39.08  23.4166
# 3      14.62  ...  8132.90  8.3917  0.03  391  2388  100.0  39.00  23.3737
# 4      14.62  ...  8129.54  8.4031  0.03  390  2388  100.0  38.99  23.4130
# ...      ...  ...      ...     ...   ...  ...   ...    ...    ...      ...
# 13091  14.62  ...  8213.28  8.4715  0.03  394  2388  100.0  38.65  23.1974
# 13092  14.62  ...  8210.85  8.4512  0.03  395  2388  100.0  38.57  23.2771
# 13093  14.62  ...  8217.24  8.4569  0.03  395  2388  100.0  38.62  23.2051
# 13094  14.62  ...  8220.48  8.4711  0.03  395  2388  100.0  38.66  23.2699
# 13095  14.62  ...  8214.64  8.4903  0.03  396  2388  100.0  38.70  23.1855
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 13091 NaN NaN
# 13092 NaN NaN
# 13093 NaN NaN
# 13094 NaN NaN
# 13095 NaN NaN
#
# [13096 rows x 28 columns]

# %%
# Drop NaN values columns
raw_train_data = raw_train_data.drop([26, 27], axis = 'columns')

# %%
# Add column names
raw_train_data.columns = ['unit_number', 'cycle', 'setting1', 'setting2', 'setting3', 'sensor1',
                'sensor2', 'sensor3', 'sensor4', 'sensor5', 'sensor6', 'sensor7', 'sensor8',
                'sensor9', 'sensor10', 'sensor11', 'sensor12', 'sensor13', 'sensor14',
                'sensor15', 'sensor16', 'sensor17', 'sensor18', 'sensor19', 'sensor20', 'sensor21']

# %%
# 3.5 Create an array which consists of End of Life (EOL) values for each units
EOL = []
for each_unit in raw_train_data['unit_number']:
    eol_values = ((raw_train_data[raw_train_data['unit_number'] == each_unit]["cycle"]).values[-1])
    EOL.append(eol_values)

# %%
# 3.6 Append "EOL" in a new column
raw_train_data["EOL"] = EOL

raw_train_data["RUL"] = raw_train_data["EOL"] - raw_train_data["cycle"]
new_train_data = raw_train_data.drop(columns=["EOL"])

# %%
# Check New Train Data
new_train_data
# Out:
#        unit_number  cycle  setting1  setting2  setting3  sensor1  sensor2  \
# 0                1      1   -0.0007   -0.0004     100.0   518.67   641.82
# 1                1      2    0.0019   -0.0003     100.0   518.67   642.15
# 2                1      3   -0.0043    0.0003     100.0   518.67   642.35
# 3                1      4    0.0007    0.0000     100.0   518.67   642.35
# 4                1      5   -0.0019   -0.0002     100.0   518.67   642.37
# ...            ...    ...       ...       ...       ...      ...      ...
# 20626          100    196   -0.0004   -0.0003     100.0   518.67   643.49
# 20627          100    197   -0.0016   -0.0005     100.0   518.67   643.54
# 20628          100    198    0.0004    0.0000     100.0   518.67   643.42
# 20629          100    199   -0.0011    0.0003     100.0   518.67   643.23
# 20630          100    200   -0.0032   -0.0005     100.0   518.67   643.85
#
#        sensor3  sensor4  sensor5  ...  sensor13  sensor14  sensor15  sensor16  \
# 0      1589.70  1400.60    14.62  ...   2388.02   8138.62    8.4195      0.03
# 1      1591.82  1403.14    14.62  ...   2388.07   8131.49    8.4318      0.03
# 2      1587.99  1404.20    14.62  ...   2388.03   8133.23    8.4178      0.03
# 3      1582.79  1401.87    14.62  ...   2388.08   8133.83    8.3682      0.03
# 4      1582.85  1406.22    14.62  ...   2388.04   8133.80    8.4294      0.03
# ...        ...      ...      ...  ...       ...       ...       ...       ...
# 20626  1597.98  1428.63    14.62  ...   2388.26   8137.60    8.4956      0.03
# 20627  1604.50  1433.58    14.62  ...   2388.22   8136.50    8.5139      0.03
# 20628  1602.46  1428.18    14.62  ...   2388.24   8141.05    8.5646      0.03
# 20629  1605.26  1426.53    14.62  ...   2388.23   8139.29    8.5389      0.03
# 20630  1600.38  1432.14    14.62  ...   2388.26   8137.33    8.5036      0.03
#
#        sensor17  sensor18  sensor19  sensor20  sensor21  RUL
# 0           392      2388     100.0     39.06   23.4190  191
# 1           392      2388     100.0     39.00   23.4236  190
# 2           390      2388     100.0     38.95   23.3442  189
# 3           392      2388     100.0     38.88   23.3739  188
# 4           393      2388     100.0     38.90   23.4044  187
# ...         ...       ...       ...       ...       ...  ...
# 20626       397      2388     100.0     38.49   22.9735    4
# 20627       395      2388     100.0     38.30   23.1594    3
# 20628       398      2388     100.0     38.44   22.9333    2
# 20629       395      2388     100.0     38.29   23.0640    1
# 20630       396      2388     100.0     38.37   23.0522    0
#
# [20631 rows x 27 columns]

# %%
delete_columns = ['setting1',
 'setting2',
 'setting3',
 'sensor1',
 'sensor5',
 'sensor6',
 'sensor9',
 'sensor10',
 'sensor14',
 'sensor16',
 'sensor18',
 'sensor19']

# %%
final_train_data = new_train_data.drop(columns=delete_columns)
final_train_data
# Out:
#        unit_number  cycle  sensor2  sensor3  sensor4  sensor7  sensor8  \
# 0                1      1   641.82  1589.70  1400.60   554.36  2388.06
# 1                1      2   642.15  1591.82  1403.14   553.75  2388.04
# 2                1      3   642.35  1587.99  1404.20   554.26  2388.08
# 3                1      4   642.35  1582.79  1401.87   554.45  2388.11
# 4                1      5   642.37  1582.85  1406.22   554.00  2388.06
# ...            ...    ...      ...      ...      ...      ...      ...
# 20626          100    196   643.49  1597.98  1428.63   551.43  2388.19
# 20627          100    197   643.54  1604.50  1433.58   550.86  2388.23
# 20628          100    198   643.42  1602.46  1428.18   550.94  2388.24
# 20629          100    199   643.23  1605.26  1426.53   550.68  2388.25
# 20630          100    200   643.85  1600.38  1432.14   550.79  2388.26
#
#        sensor11  sensor12  sensor13  sensor15  sensor17  sensor20  sensor21  \
# 0         47.47    521.66   2388.02    8.4195       392     39.06   23.4190
# 1         47.49    522.28   2388.07    8.4318       392     39.00   23.4236
# 2         47.27    522.42   2388.03    8.4178       390     38.95   23.3442
# 3         47.13    522.86   2388.08    8.3682       392     38.88   23.3739
# 4         47.28    522.19   2388.04    8.4294       393     38.90   23.4044
# ...         ...       ...       ...       ...       ...       ...       ...
# 20626     48.07    519.49   2388.26    8.4956       397     38.49   22.9735
# 20627     48.04    519.68   2388.22    8.5139       395     38.30   23.1594
# 20628     48.09    520.01   2388.24    8.5646       398     38.44   22.9333
# 20629     48.39    519.67   2388.23    8.5389       395     38.29   23.0640
# 20630     48.20    519.30   2388.26    8.5036       396     38.37   23.0522
#
#        RUL
# 0      191
# 1      190
# 2      189
# 3      188
# 4      187
# ...    ...
# 20626    4
# 20627    3
# 20628    2
# 20629    1
# 20630    0
#
# [20631 rows x 15 columns]

# %%
# Create a processed final train data
final_train_data.to_csv('Processed_Train_FD001.csv', index=None)

# %% [markdown]
# ## Create a function for data processing

# %%
def create_dataset(data):
    # Drop NaN values columns
    data = data.drop([26, 27], axis = 'columns')
    # Add column names
    data.columns = ['unit_number', 'cycle', 'setting1', 'setting2', 'setting3', 'sensor1',
                    'sensor2', 'sensor3', 'sensor4', 'sensor5', 'sensor6', 'sensor7', 'sensor8',
                    'sensor9', 'sensor10', 'sensor11', 'sensor12', 'sensor13', 'sensor14',
                    'sensor15', 'sensor16', 'sensor17', 'sensor18', 'sensor19', 'sensor20', 'sensor21']
    
    # 3.5 Create an array which consists of End of Life (EOL) values for each units
    EOL = []
    for each_unit in data['unit_number']:
        eol_values = ((data[data['unit_number'] == each_unit]["cycle"]).values[-1])
        EOL.append(eol_values)
        
    # 3.6 Append "EOL" in a new column
    data["EOL"] = EOL
    
    data["RUL"] = data["EOL"] - data["cycle"]
    new_data = data.drop(columns=["EOL"])
    
    delete_columns = ['setting1',
                      'setting2',
                     'setting3',
                     'sensor1',
                     'sensor5',
                     'sensor6',
                     'sensor9',
                     'sensor10',
                     'sensor14',
                     'sensor16',
                     'sensor18',
                     'sensor19']

            
    final_data = new_data.drop(columns=delete_columns)
    
    return final_data

# %%
# Test Final dataset
final_test_data = create_dataset(raw_test_data)
final_test_data.to_csv('Processed_Test_FD001.csv', index=None)
