# %%
# Import necessary libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Define Dataset Path
dataset_path = 'CMAPSS/'
print(dataset_path)
# Out:
# CMAPSS/

# %%
# Define column names
index_names = ['unit_number', 'time_cycle']
operational_setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['sensor_{}'.format(i) for i in range(1, 22)]
column_names = index_names + operational_setting_names + sensor_names

# %%
# Read the data files
# Read the data files with the 'python' engine
train_file = pd.read_csv((dataset_path+'train_FD004.txt'), sep='\\s+', header=None, names=column_names, engine='python')
test_file = pd.read_csv((dataset_path+'test_FD004.txt'), sep='\\s+', header=None, names=column_names, engine='python')
y_test = pd.read_csv((dataset_path+'RUL_FD004.txt'), sep='\\s+', header=None, names=['RUL'], engine='python')

# Check and print few data
train_file.head()
# Out:
#    unit_number  time_cycle  setting_1  setting_2  setting_3  sensor_1  \
# 0            1           1    42.0049     0.8400      100.0    445.00
# 1            1           2    20.0020     0.7002      100.0    491.19
# 2            1           3    42.0038     0.8409      100.0    445.00
# 3            1           4    42.0000     0.8400      100.0    445.00
# 4            1           5    25.0063     0.6207       60.0    462.54
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0    549.68   1343.43   1112.93      3.91  ...     129.78    2387.99
# 1    606.07   1477.61   1237.50      9.35  ...     312.59    2387.73
# 2    548.95   1343.12   1117.05      3.91  ...     129.62    2387.97
# 3    548.70   1341.24   1118.03      3.91  ...     129.80    2388.02
# 4    536.10   1255.23   1033.59      7.05  ...     164.11    2028.08
#
#    sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# ...

# %%
# Computing RUL
def add_remaining_useful_life(df):
    # Get the total number of cycles for each unit
    grouped_by_unit = df.groupby(by="unit_number")
    max_cycle = grouped_by_unit["time_cycle"].max()
    
    # Merge the max cycle back into the original frame
    result_frame = df.merge(max_cycle.to_frame(name='max_cycle'), left_on='unit_number', right_index=True)
    
    # Calculate remaining useful life for each row
    remaining_useful_life = result_frame["max_cycle"] - result_frame["time_cycle"]
    result_frame["RUL"] = remaining_useful_life
    
    # drop max_cycle as it's no longer needed
    result_frame = result_frame.drop("max_cycle", axis=1)
    return result_frame

# %%
train = add_remaining_useful_life(train_file)
# train[index_names+['RUL']].head()
train.head()
# Out:
#    unit_number  time_cycle  setting_1  setting_2  setting_3  sensor_1  \
# 0            1           1    42.0049     0.8400      100.0    445.00
# 1            1           2    20.0020     0.7002      100.0    491.19
# 2            1           3    42.0038     0.8409      100.0    445.00
# 3            1           4    42.0000     0.8400      100.0    445.00
# 4            1           5    25.0063     0.6207       60.0    462.54
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    549.68   1343.43   1112.93      3.91  ...    2387.99    8074.83
# 1    606.07   1477.61   1237.50      9.35  ...    2387.73    8046.13
# 2    548.95   1343.12   1117.05      3.91  ...    2387.97    8066.62
# 3    548.70   1341.24   1118.03      3.91  ...    2388.02    8076.05
# 4    536.10   1255.23   1033.59      7.05  ...    2028.08    7865.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
test = add_remaining_useful_life(test_file)
# train[index_names+['RUL']].head()
test.head()
# Out:
#    unit_number  time_cycle  setting_1  setting_2  setting_3  sensor_1  \
# 0            1           1    20.0072     0.7000      100.0    491.19
# 1            1           2    24.9984     0.6200       60.0    462.54
# 2            1           3    42.0000     0.8420      100.0    445.00
# 3            1           4    42.0035     0.8402      100.0    445.00
# 4            1           5    35.0079     0.8400      100.0    449.44
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    606.67   1481.04   1227.81      9.35  ...    2387.78    8048.98
# 1    536.22   1256.17   1031.48      7.05  ...    2028.09    7863.46
# 2    549.23   1340.13   1105.88      3.91  ...    2387.95    8071.13
# 3    549.19   1339.70   1107.26      3.91  ...    2387.90    8078.89
# 4    555.10   1353.04   1117.80      5.48  ...    2387.87    8057.83
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
# Specify the file path where you want to save the CSV file
final_train_path = 'final_train_FD004.csv'
final_test_path = 'final_test_FD004.csv'

# %%
# Export the DataFrame to a Final Train CSV file
train.to_csv(final_train_path, index=False)  # Set index=False to exclude the DataFrame's index in the output

print(f'DataFrame exported to {final_train_path}')
# Out:
# DataFrame exported to final_train_FD004.csv

# %%
# Export the DataFrame to a Final Train CSV file
test.to_csv(final_test_path, index=False)  # Set index=False to exclude the DataFrame's index in the output

print(f'DataFrame exported to {final_test_path}')
# Out:
# DataFrame exported to final_test_FD004.csv
